# %%
import pandas as pd
import pymongo
import os
from dotenv import load_dotenv

df = pd.read_csv("bank_transactions_data_2.csv")
df.head()
# Out:
#   TransactionID AccountID  TransactionAmount      TransactionDate  \
# 0      TX000001   AC00128              14.09  2023-04-11 16:29:14
# 1      TX000002   AC00455             376.24  2023-06-27 16:44:19
# 2      TX000003   AC00019             126.29  2023-07-10 18:16:08
# 3      TX000004   AC00070             184.50  2023-05-05 16:32:11
# 4      TX000005   AC00411              13.45  2023-10-16 17:51:24
#
#   TransactionType   Location DeviceID      IP Address MerchantID Channel  \
# 0           Debit  San Diego  D000380  162.198.218.92       M015     ATM
# 1           Debit    Houston  D000051     13.149.61.4       M052     ATM
# 2           Debit       Mesa  D000235  215.97.143.157       M009  Online
# 3           Debit    Raleigh  D000187  200.13.225.150       M002  Online
# 4          Credit    Atlanta  D000308    65.164.3.100       M091  Online
#
#    CustomerAge CustomerOccupation  TransactionDuration  LoginAttempts  \
# 0           70             Doctor                   81              1
# 1           68             Doctor                  141              1
# 2           19            Student                   56              1
# 3           26            Student                   25              1
# 4           26            Student                  198              1
#
#    AccountBalance PreviousTransactionDate
# 0         5112.21     2024-11-04 08:08:08
# 1        13758.91     2024-11-04 08:09:35
# 2         1122.35     2024-11-04 08:07:04
# 3         8569.06     2024-11-04 08:09:06
# 4         7429.40     2024-11-04 08:06:39

# %%
data = df.to_dict(orient='records')
data
# Out:
# [{'TransactionID': 'TX000001',
#   'AccountID': 'AC00128',
#   'TransactionAmount': 14.09,
#   'TransactionDate': '2023-04-11 16:29:14',
#   'TransactionType': 'Debit',
#   'Location': 'San Diego',
#   'DeviceID': 'D000380',
#   'IP Address': '162.198.218.92',
#   'MerchantID': 'M015',
#   'Channel': 'ATM',
#   'CustomerAge': 70,
#   'CustomerOccupation': 'Doctor',
#   'TransactionDuration': 81,
#   'LoginAttempts': 1,
#   'AccountBalance': 5112.21,
#   'PreviousTransactionDate': '2024-11-04 08:08:08'},
#  {'TransactionID': 'TX000002',
#   'AccountID': 'AC00455',
#   'TransactionAmount': 376.24,
#   'TransactionDate': '2023-06-27 16:44:19',
#   'TransactionType': 'Debit',
#   'Location': 'Houston',
#   'DeviceID': 'D000051',
#   'IP Address': '13.149.61.4',
#   'MerchantID': 'M052',
#   'Channel': 'ATM',
#   'CustomerAge': 68,
#   'CustomerOccupation': 'Doctor',
#   'TransactionDuration': 141,
#   'LoginAttempts': 1,
#   'AccountBalance': 13758.91,
#   'PreviousTransactionDate': '2024-11-04 08:09:35'},
#  {'TransactionID': 'TX000003',
#   'AccountID': 'AC00019',
#   'TransactionAmount': 126.29,
#   'TransactionDate': '2023-07-10 18:16:08',
#   'TransactionType': 'Debit',
#   'Location': 'Mesa',
#   'DeviceID': 'D000235',
#   'IP Address': '215.97.143.157',
#   'MerchantID': 'M009',
#   'Channel': 'Online',
#   'CustomerAge': 19,
#   'CustomerOccupation': 'Student',
#   'TransactionDuration': 56,
#   'LoginAttempts': 1,
#   'AccountBalance': 1122.35,
#   'PreviousTransactionDate': '2024-11-04 08:07:04'},
#  {'TransactionID': 'TX000004',
#   'AccountID': 'AC00070',
#   'TransactionAmount': 184.5,
#   'TransactionDate': '2023-05-05 16:32:11',
#   'TransactionType': 'Debit',
#   'Location': 'Raleigh',
#   'DeviceID': 'D000187',
#   'IP Address': '200.13.225.150',
#   'MerchantID': 'M002',
#   'Channel': 'Online',
#   'CustomerAge': 26,
#   'CustomerOccupation': 'Student',
#   'TransactionDuration': 25,
#   'LoginAttempts': 1,
#   'AccountBalance': 8569.06,
#   'PreviousTransactionDate': '2024-11-04 08:09:06'},
#  {'TransactionID': 'TX000005',
#   'AccountID': 'AC00411',
#   'TransactionAmount': 13.45,
#   'TransactionDate': '2023-10-16 17:51:24',
#   'TransactionType': 'Credit',
#   'Location': 'Atlanta',
#   'DeviceID': 'D000308',
#   'IP Address': '65.164.3.100',
#   'MerchantID': 'M091',
#   'Channel': 'Online',
#   'CustomerAge': 26,
#   'CustomerOccupation': 'Student',
#   'TransactionDuration': 198,
#   'LoginAttempts': 1,
#   'AccountBalance': 7429.4,
#   'PreviousTransactionDate': '2024-11-04 08:06:39'},
#  {'TransactionID': 'TX000006',
#   'AccountID': 'AC00393',
#   'TransactionAmount': 92.15,
#   'TransactionDate': '2023-04-03 17:15:01',
#   'TransactionType': 'Debit',
#   'Location': 'Oklahoma City',
#   'DeviceID': 'D000579',
#   'IP Address': '117.67.192.211',
#   'MerchantID': 'M054',
#   'Channel': 'ATM',
#   'CustomerAge': 18,
#   'CustomerOccupation': 'Student',
#   'TransactionDuration': 172,
#   'LoginAttempts': 1,
#   'AccountBalance': 781.68,
#   'PreviousTransactionDate': '2024-11-04 08:06:36'},
#  {'TransactionID': 'TX000007',
#   'AccountID': 'AC00199',
#   'TransactionAmount': 7.08,
#   'TransactionDate': '2023-02-15 16:36:48',
#   'TransactionType': 'Credit',
#   'Location': 'Seattle',
#   'DeviceID': 'D000241',
#   'IP Address': '140.212.253.222',
#   'MerchantID': 'M019',
#   'Channel': 'ATM',
#   'CustomerAge': 37,
#   'CustomerOccupation': 'Doctor',
#   'TransactionDuration': 139,
#   'LoginAttempts': 1,
#   'AccountBalance': 13316.71,
#   'PreviousTransactionDate': '2024-11-04 08:10:09'},
#  {'TransactionID': 'TX000008',
#   'AccountID': 'AC00069',
#   'TransactionAmount': 171.42,
#   'TransactionDate': '2023-05-08 17:47:59',
#   'TransactionType': 'Credit',
#   'Location': 'Indianapolis',
#   'DeviceID': 'D000500',
#   'IP Address': '92.214.76.157',
#   'MerchantID': 'M020',
#   'Channel': 'Branch',
#   'CustomerAge': 67,
#   'CustomerOccupation': 'Retired',
#   'TransactionDuration': 291,
#   'LoginAttempts': 1,
#   'AccountBalance': 2796.24,
#   'PreviousTransactionDate': '2024-11-04 08:10:55'},
#  {'TransactionID': 'TX000009',
#   'AccountID': 'AC00135',
#   'TransactionAmount': 106.23,
#   'TransactionDate': '2023-03-21 16:59:46',
#   'TransactionType': 'Credit',
#   'Location': 'Detroit',
#   'DeviceID': 'D000690',
#   'IP Address': '24.148.92.177',
#   'MerchantID': 'M035',
#   'Channel': 'Branch',
#   'CustomerAge': 51,
#   'CustomerOccupation': 'Engineer',
#   'TransactionDuration': 86,
#   'LoginAttempts': 1,
#   'AccountBalance': 9095.14,
#   'PreviousTransactionDate': '2024-11-04 08:11:14'},
#  {'TransactionID': 'TX000010',
#   'AccountID': 'AC00385',
#   'TransactionAmount': 815.96,
#   'TransactionDate': '2023-03-31 16:06:57',
#   'TransactionType': 'Debit',
#   'Location': 'Nashville',
#   'DeviceID': 'D000199',
#   'IP Address': '32.169.88.41',
#   'MerchantID': 'M007',
#   'Channel': 'ATM',
#   'CustomerAge': 55,
#   'CustomerOccupation': 'Doctor',
#   'TransactionDuration': 120,
#   'LoginAttempts': 1,
#   'AccountBalance': 1021.88,
#   'PreviousTransactionDate': '2024-11-04 08:06:32'},
#  {'TransactionID': 'TX000011',
#   'AccountID': 'AC00150',
#   'TransactionAmount': 17.78,
#   'TransactionDate': '2023-03-14 16:46:10',
#   'TransactionType': 'Credit',
#   'Location': 'Albuquerque',
#   'DeviceID': 'D000205',
#   'IP Address': '213.15.9.253',
#   'MerchantID': 'M073',
#   'Channel': 'Online',
#   'CustomerAge': 52,
#   'CustomerOccupation': 'Engineer',
#   'TransactionDuration': 59,
#   'LoginAttempts': 1,
#   'AccountBalance': 7599.52,
#   'PreviousTransactionDate': '2024-11-04 08:06:45'},
#  {'TransactionID': 'TX000012',
#   'AccountID': 'AC00459',
#   'TransactionAmount': 190.02,
#   'TransactionDate': '2023-02-06 17:30:00',
#   'TransactionType': 'Debit',
#   'Location': 'Memphis',
#   'DeviceID': 'D000589',
#   'IP Address': '116.175.11.222',
#   'MerchantID': 'M030',
#   'Channel': 'Online',
#   'CustomerAge': 21,
#   'CustomerOccupation': 'Student',
#   'TransactionDuration': 173,
#   'LoginAttempts': 1,
#   'AccountBalance': 1528.81,
#   'PreviousTransactionDate': '2024-11-04 08:07:12'},
#  {'TransactionID': 'TX000013',
#   'AccountID': 'AC00392',
#   'TransactionAmount': 494.52,
#   'TransactionDate': '2023-06-07 17:21:28',
#   'TransactionType': 'Credit',
#   'Location': 'Mesa',
#   'DeviceID': 'D000032',
#   'IP Address': '210.98.198.143',
#   'MerchantID': 'M057',
#   'Channel': 'Branch',
#   'CustomerAge': 24,
#   'CustomerOccupation': 'Student',
#   'TransactionDuration': 111,
#   'LoginAttempts': 1,
#   'AccountBalance': 1620.02,
#   'PreviousTransactionDate': '2024-11-04 08:08:38'},
#  {'TransactionID': 'TX000014',
#   'AccountID': 'AC00264',
#   'TransactionAmount': 781.76,
#   'TransactionDate': '2023-11-20 16:39:15',
#   'TransactionType': 'Debit',
#   'Location': 'Memphis',
#   'DeviceID': 'D000054',
#   'IP Address': '193.83.0.183',
#   'MerchantID': 'M025',
#   'Channel': 'ATM',
#   'CustomerAge': 26,
#   'CustomerOccupation': 'Student',
#   'TransactionDuration': 123,
#   'LoginAttempts': 1,
#   'AccountBalance': 189.69,
#   'PreviousTransactionDate': '2024-11-04 08:07:06'},
#  {'TransactionID': 'TX000015',
#   'AccountID': 'AC00085',
#   'TransactionAmount': 166.99,
#   'TransactionDate': '2023-02-13 16:53:57',
#   'TransactionType': 'Debit',
#   'Location': 'Louisville',
#   'DeviceID': 'D000309',
#   'IP Address': '188.124.181.12',
#   'MerchantID': 'M017',
#   'Channel': 'Online',
#   'CustomerAge': 18,
#   'CustomerOccupation': 'Student',
#   'TransactionDuration': 134,
#   'LoginAttempts': 1,
#   'AccountBalance': 299.93,
#   'PreviousTransactionDate': '2024-11-04 08:10:09'},
#  {'TransactionID': 'TX000016',
#   'AccountID': 'AC00270',
#   'TransactionAmount': 465.45,
#   'TransactionDate': '2023-12-12 16:23:31',
#   'TransactionType': 'Debit',
#   'Location': 'Denver',
#   'DeviceID': 'D000466',
#   'IP Address': '221.169.49.152',
#   'MerchantID': 'M025',
#   'Channel': 'ATM',
#   'CustomerAge': 36,
#   'CustomerOccupation': 'Engineer',
#   'TransactionDuration': 129,
#   'LoginAttempts': 1,
#   'AccountBalance': 3465.54,
#   'PreviousTransactionDate': '2024-11-04 08:12:19'},
#  {'TransactionID': 'TX000017',
#   'AccountID': 'AC00317',
#   'TransactionAmount': 555.8,
#   'TransactionDate': '2023-10-30 16:52:49',
#   'TransactionType': 'Credit',
#   'Location': 'Austin',
#   'DeviceID': 'D000671',
#   'IP Address': '53.218.177.171',
#   'MerchantID': 'M048',
#   'Channel': 'Branch',
#   'CustomerAge': 19,
#   'CustomerOccupation': 'Student',
#   'TransactionDuration': 158,
#   'LoginAttempts': 1,
#   'AccountBalance': 1131.26,
#   'PreviousTransactionDate': '2024-11-04 08:07:35'},
#  {'TransactionID': 'TX000018',
#   'AccountID': 'AC00359',
#   'TransactionAmount': 492.93,
#   'TransactionDate': '2023-12-14 18:32:14',
#   'TransactionType': 'Debit',
#   'Location': 'Columbus',
#   'DeviceID': 'D000432',
#   'IP Address': '114.223.129.47',
#   'MerchantID': 'M059',
#   'Channel': 'Online',
#   'CustomerAge': 39,
#   'CustomerOccupation': 'Engineer',
#   'TransactionDuration': 234,
#   'LoginAttempts': 1,
#   'AccountBalance': 5109.97,
#   'PreviousTransactionDate': '2024-11-04 08:11:51'},
#  {'TransactionID': 'TX000019',
#   'AccountID': 'AC00242',
#   'TransactionAmount': 18.68,
#   'TransactionDate': '2023-02-21 16:56:50',
#   'TransactionType': 'Credit',
#   'Location': 'Albuquerque',
#   'DeviceID': 'D000530',
#   'IP Address': '93.218.115.132',
#   'MerchantID': 'M054',
#   'Channel': 'Branch',
#   'CustomerAge': 59,
#   'CustomerOccupation': 'Retired',
#   'TransactionDuration': 106,
#   'LoginAttempts': 1,
#   'AccountBalance': 7948.37,
#   'PreviousTransactionDate': '2024-11-04 08:12:01'},
#  {'TransactionID': 'TX000020',
#   'AccountID': 'AC00285',
#   'TransactionAmount': 71.48,
#   'TransactionDate': '2023-06-08 18:18:50',
#   'TransactionType': 'Credit',
#   'Location': 'Columbus',
#   'DeviceID': 'D000039',
#   'IP Address': '120.170.93.69',
#   'MerchantID': 'M039',
#   'Channel': 'Online',
#   'CustomerAge': 18,
#   'CustomerOccupation': 'Student',
#   'TransactionDuration': 169,
#   'LoginAttempts': 1,
#   'AccountBalance': 6568.59,
#   'PreviousTransactionDate': '2024-11-04 08:09:20'},
#  {'TransactionID': 'TX000021',
#   'AccountID': 'AC00002',
#   'TransactionAmount': 59.32,
#   'TransactionDate': '2023-02-28 16:36:58',
#   'TransactionType': 'Debit',
#   'Location': 'Los Angeles',
#   'DeviceID': 'D000152',
#   'IP Address': '116.44.12.250',
#   'MerchantID': 'M040',
#   'Channel': 'Branch',
#   'CustomerAge': 71,
#   'CustomerOccupation': 'Retired',
#   'TransactionDuration': 38,
#   'LoginAttempts': 1,
#   'AccountBalance': 5750.89,
#   'PreviousTransactionDate': '2024-11-04 08:09:24'},
#  {'TransactionID': 'TX000022',
#   'AccountID': 'AC00014',
#   'TransactionAmount': 85.77,
#   'TransactionDate': '2023-08-11 18:31:31',
#   'TransactionType': 'Debit',
#   'Location': 'Las Vegas',
#   'DeviceID': 'D000268',
#   'IP Address': '59.132.247.252',
#   'MerchantID': 'M065',
#   'Channel': 'Branch',
#   'CustomerAge': 38,
#   'CustomerOccupation': 'Doctor',
#   'TransactionDuration': 93,
#   'LoginAttempts': 1,
#   'AccountBalance': 9146.19,
#   'PreviousTransactionDate': '2024-11-04 08:08:13'},
#  {'TransactionID': 'TX000023',
#   'AccountID': 'AC00095',
#   'TransactionAmount': 52.2,
#   'TransactionDate': '2023-06-06 18:54:15',
#   'TransactionType': 'Debit',
#   'Location': 'Atlanta',
#   'DeviceID': 'D000142',
#   'IP Address': '133.63.96.21',
#   'MerchantID': 'M022',
#   'Channel': 'Online',
#   'CustomerAge': 39,
#   'CustomerOccupation': 'Engineer',
#   'TransactionDuration': 120,
#   'LoginAttempts': 1,
#   'AccountBalance': 8974.93,
#   'PreviousTransactionDate': '2024-11-04 08:07:01'},
#  {'TransactionID': 'TX000024',
#   'AccountID': 'AC00453',
#   'TransactionAmount': 345.84,
#   'TransactionDate': '2023-05-02 18:25:46',
#   'TransactionType': 'Debit',
#   'Location': 'Fort Worth',
#   'DeviceID': 'D000162',
#   'IP Address': '191.82.103.198',
#   'MerchantID': 'M083',
#   'Channel': 'Online',
#   'CustomerAge': 22,
#   'CustomerOccupation': 'Student',
#   'TransactionDuration': 142,
#   'LoginAttempts': 3,
#   'AccountBalance': 1402.5,
#   'PreviousTransactionDate': '2024-11-04 08:07:04'},
#  {'TransactionID': 'TX000025',
#   'AccountID': 'AC00241',
#   'TransactionAmount': 145.54,
#   'TransactionDate': '2023-03-02 16:43:56',
#   'TransactionType': 'Debit',
#   'Location': 'Raleigh',
#   'DeviceID': 'D000036',
#   'IP Address': '119.186.154.104',
#   'MerchantID': 'M028',
#   'Channel': 'Online',
#   'CustomerAge': 21,
#   'CustomerOccupation': 'Student',
#   'TransactionDuration': 96,
#   'LoginAttempts': 1,
#   'AccountBalance': 1930.96,
#   'PreviousTransactionDate': '2024-11-04 08:07:09'},
#  {'TransactionID': 'TX000026',
#   'AccountID': 'AC00041',
#   'TransactionAmount': 7.49,
#   'TransactionDate': '2023-10-20 17:53:13',
#   'TransactionType': 'Credit',
#   'Location': 'Houston',
#   'DeviceID': 'D000671',
#   'IP Address': '81.248.235.147',
#   'MerchantID': 'M043',
#   'Channel': 'Online',
#   'CustomerAge': 65,
#   'CustomerOccupation': 'Retired',
#   'TransactionDuration': 276,
#   'LoginAttempts': 1,
#   'AccountBalance': 3634.67,
#   'PreviousTransactionDate': '2024-11-04 08:09:44'},
#  {'TransactionID': 'TX000027',
#   'AccountID': 'AC00441',
#   'TransactionAmount': 246.93,
#   'TransactionDate': '2023-04-17 16:37:01',
#   'TransactionType': 'Debit',
#   'Location': 'Miami',
#   'DeviceID': 'D000046',
#   'IP Address': '55.154.161.250',
#   'MerchantID': 'M029',
#   'Channel': 'ATM',
#   'CustomerAge': 23,
#   'CustomerOccupation': 'Student',
#   'TransactionDuration': 158,
#   'LoginAttempts': 5,
#   'AccountBalance': 673.35,
#   'PreviousTransactionDate': '2024-11-04 08:11:38'},
#  {'TransactionID': 'TX000028',
#   'AccountID': 'AC00057',
#   'TransactionAmount': 40.32,
#   'TransactionDate': '2023-03-29 16:42:38',
#   'TransactionType': 'Debit',
#   'Location': 'Milwaukee',
#   'DeviceID': 'D000310',
#   'IP Address': '21.28.32.1',
#   'MerchantID': 'M008',
#   'Channel': 'Branch',
#   'CustomerAge': 37,
#   'CustomerOccupation': 'Engineer',
#   'TransactionDuration': 95,
#   'LoginAttempts': 1,
#   'AccountBalance': 2686.52,
#   'PreviousTransactionDate': '2024-11-04 08:11:59'},
#  {'TransactionID': 'TX000029',
#   'AccountID': 'AC00390',
#   'TransactionAmount': 127.45,
#   'TransactionDate': '2023-01-24 16:18:32',
#   'TransactionType': 'Debit',
#   'Location': 'Las Vegas',
#   'DeviceID': 'D000232',
#   'IP Address': '152.234.65.155',
#   'MerchantID': 'M092',
#   'Channel': 'Online',
#   'CustomerAge': 44,
#   'CustomerOccupation': 'Doctor',
#   'TransactionDuration': 197,
#   'LoginAttempts': 1,
#   'AccountBalance': 1772.06,
#   'PreviousTransactionDate': '2024-11-04 08:11:22'},
#  {'TransactionID': 'TX000030',
#   'AccountID': 'AC00313',
#   'TransactionAmount': 56.17,
#   'TransactionDate': '2023-09-20 16:55:42',
#   'TransactionType': 'Debit',
#   'Location': 'Detroit',
#   'DeviceID': 'D000297',
#   'IP Address': '33.28.138.82',
#   'MerchantID': 'M043',
#   'Channel': 'Branch',
#   'CustomerAge': 27,
#   'CustomerOccupation': 'Student',
#   'TransactionDuration': 283,
#   'LoginAttempts': 1,
#   'AccountBalance': 1351.69,
#   'PreviousTransactionDate': '2024-11-04 08:08:30'},
#  {'TransactionID': 'TX000031',
#   'AccountID': 'AC00367',
#   'TransactionAmount': 28.31,
#   'TransactionDate': '2023-07-17 17:49:22',
#   'TransactionType': 'Credit',
#   'Location': 'Miami',
#   'DeviceID': 'D000587',
#   'IP Address': '35.67.21.23',
#   'MerchantID': 'M091',
#   'Channel': 'Online',
#   'CustomerAge': 59,
#   'CustomerOccupation': 'Doctor',
#   'TransactionDuration': 20,
#   'LoginAttempts': 1,
#   'AccountBalance': 8334.47,
#   'PreviousTransactionDate': '2024-11-04 08:09:17'},
#  {'TransactionID': 'TX000032',
#   'AccountID': 'AC00291',
#   'TransactionAmount': 59.12,
#   'TransactionDate': '2023-02-06 16:24:24',
#   'TransactionType': 'Debit',
#   'Location': 'Baltimore',
#   'DeviceID': 'D000282',
#   'IP Address': '187.199.178.27',
#   'MerchantID': 'M053',
#   'Channel': 'ATM',
#   'CustomerAge': 29,
#   'CustomerOccupation': 'Doctor',
#   'TransactionDuration': 257,
#   'LoginAttempts': 1,
#   'AccountBalance': 9823.64,
#   'PreviousTransactionDate': '2024-11-04 08:06:58'},
#  {'TransactionID': 'TX000033',
#   'AccountID': 'AC00060',
#   'TransactionAmount': 396.45,
#   'TransactionDate': '2023-09-25 16:26:00',
#   'TransactionType': 'Debit',
#   'Location': 'New York',
#   'DeviceID': 'D000621',
#   'IP Address': '133.67.250.163',
#   'MerchantID': 'M007',
#   'Channel': 'ATM',
#   'CustomerAge': 49,
#   'CustomerOccupation': 'Engineer',
#   'TransactionDuration': 168,
#   'LoginAttempts': 3,
#   'AccountBalance': 9690.15,
#   'PreviousTransactionDate': '2024-11-04 08:11:13'},
#  {'TransactionID': 'TX000034',
#   'AccountID': 'AC00359',
#   'TransactionAmount': 877.81,
#   'TransactionDate': '2023-03-13 17:23:24',
#   'TransactionType': 'Debit',
#   'Location': 'Los Angeles',
#   'DeviceID': 'D000111',
#   'IP Address': '134.140.85.231',
#   'MerchantID': 'M094',
#   'Channel': 'Online',
#   'CustomerAge': 22,
#   'CustomerOccupation': 'Student',
#   'TransactionDuration': 150,
#   'LoginAttempts': 1,
#   'AccountBalance': 399.0,
#   'PreviousTransactionDate': '2024-11-04 08:07:50'},
#  {'TransactionID': 'TX000035',
#   'AccountID': 'AC00365',
#   'TransactionAmount': 255.26,
#   'TransactionDate': '2023-10-27 16:42:49',
#   'TransactionType': 'Credit',
#   'Location': 'San Francisco',
#   'DeviceID': 'D000357',
#   'IP Address': '92.214.76.157',
#   'MerchantID': 'M002',
#   'Channel': 'Branch',
#   'CustomerAge': 45,
#   'CustomerOccupation': 'Doctor',
#   'TransactionDuration': 50,
#   'LoginAttempts': 1,
#   'AccountBalance': 14815.87,
#   'PreviousTransactionDate': '2024-11-04 08:10:51'},
#  {'TransactionID': 'TX000036',
#   'AccountID': 'AC00267',
#   'TransactionAmount': 124.76,
#   'TransactionDate': '2023-10-16 16:32:56',
#   'TransactionType': 'Debit',
#   'Location': 'Seattle',
#   'DeviceID': 'D000042',
#   'IP Address': '59.145.242.13',
#   'MerchantID': 'M002',
#   'Channel': 'Branch',
#   'CustomerAge': 49,
#   'CustomerOccupation': 'Engineer',
#   'TransactionDuration': 45,
#   'LoginAttempts': 1,
#   'AccountBalance': 5764.72,
#   'PreviousTransactionDate': '2024-11-04 08:06:23'},
#  {'TransactionID': 'TX000037',
#   'AccountID': 'AC00404',
#   'TransactionAmount': 78.13,
#   'TransactionDate': '2023-11-21 16:58:44',
#   'TransactionType': 'Debit',
#   'Location': 'Milwaukee',
#   'DeviceID': 'D000250',
#   'IP Address': '33.28.138.82',
#   'MerchantID': 'M028',
#   'Channel': 'Branch',
#   'CustomerAge': 26,
#   'CustomerOccupation': 'Student',
#   'TransactionDuration': 145,
#   'LoginAttempts': 1,
#   'AccountBalance': 900.61,
#   'PreviousTransactionDate': '2024-11-04 08:12:18'},
#  {'TransactionID': 'TX000038',
#   'AccountID': 'AC00202',
#   'TransactionAmount': 649.28,
#   'TransactionDate': '2023-03-02 17:53:32',
#   'TransactionType': 'Debit',
#   'Location': 'San Jose',
#   'DeviceID': 'D000448',
#   'IP Address': '73.108.76.238',
#   'MerchantID': 'M074',
#   'Channel': 'ATM',
#   'CustomerAge': 75,
#   'CustomerOccupation': 'Retired',
#   'TransactionDuration': 137,
#   'LoginAttempts': 1,
#   'AccountBalance': 4875.86,
#   'PreviousTransactionDate': '2024-11-04 08:11:15'},
#  {'TransactionID': 'TX000039',
#   'AccountID': 'AC00478',
#   'TransactionAmount': 795.31,
#   'TransactionDate': '2023-10-12 17:07:40',
#   'TransactionType': 'Debit',
#   'Location': 'Mesa',
#   'DeviceID': 'D000077',
#   'IP Address': '49.29.37.185',
#   'MerchantID': 'M048',
#   'Channel': 'ATM',
#   'CustomerAge': 66,
#   'CustomerOccupation': 'Doctor',
#   'TransactionDuration': 90,
#   'LoginAttempts': 2,
#   'AccountBalance': 7914.88,
#   'PreviousTransactionDate': '2024-11-04 08:11:17'},
#  {'TransactionID': 'TX000040',
#   'AccountID': 'AC00405',
#   'TransactionAmount': 335.63,
#   'TransactionDate': '2023-01-24 17:17:20',
#   'TransactionType': 'Debit',
#   'Location': 'Oklahoma City',
#   'DeviceID': 'D000038',
#   'IP Address': '49.20.211.229',
#   'MerchantID': 'M040',
#   'Channel': 'Online',
#   'CustomerAge': 55,
#   'CustomerOccupation': 'Retired',
#   'TransactionDuration': 216,
#   'LoginAttempts': 1,
#   'AccountBalance': 1019.39,
#   'PreviousTransactionDate': '2024-11-04 08:07:32'},
#  {'TransactionID': 'TX000041',
#   'AccountID': 'AC00421',
#   'TransactionAmount': 328.47,
#   'TransactionDate': '2023-07-31 18:39:50',
#   'TransactionType': 'Debit',
#   'Location': 'San Antonio',
#   'DeviceID': 'D000557',
#   'IP Address': '6.234.101.35',
#   'MerchantID': 'M014',
#   'Channel': 'ATM',
#   'CustomerAge': 63,
#   'CustomerOccupation': 'Retired',
#   'TransactionDuration': 119,
#   'LoginAttempts': 1,
#   'AccountBalance': 4323.66,
#   'PreviousTransactionDate': '2024-11-04 08:07:31'},
#  {'TransactionID': 'TX000042',
#   'AccountID': 'AC00480',
#   'TransactionAmount': 34.02,
#   'TransactionDate': '2023-01-09 16:13:21',
#   'TransactionType': 'Debit',
#   'Location': 'Philadelphia',
#   'DeviceID': 'D000627',
#   'IP Address': '109.105.179.186',
#   'MerchantID': 'M046',
#   'Channel': 'Online',
#   'CustomerAge': 38,
#   'CustomerOccupation': 'Doctor',
#   'TransactionDuration': 19,
#   'LoginAttempts': 1,
#   'AccountBalance': 14214.48,
#   'PreviousTransactionDate': '2024-11-04 08:11:45'},
#  {'TransactionID': 'TX000043',
#   'AccountID': 'AC00120',
#   'TransactionAmount': 241.42,
#   'TransactionDate': '2023-04-20 18:57:43',
#   'TransactionType': 'Credit',
#   'Location': 'Charlotte',
#   'DeviceID': 'D000198',
#   'IP Address': '60.89.202.192',
#   'MerchantID': 'M044',
#   'Channel': 'Online',
#   'CustomerAge': 57,
#   'CustomerOccupation': 'Doctor',
#   'TransactionDuration': 116,
#   'LoginAttempts': 1,
#   'AccountBalance': 13357.02,
#   'PreviousTransactionDate': '2024-11-04 08:09:03'},
#  {'TransactionID': 'TX000044',
#   'AccountID': 'AC00117',
#   'TransactionAmount': 55.32,
#   'TransactionDate': '2023-04-12 16:03:37',
#   'TransactionType': 'Debit',
#   'Location': 'Tucson',
#   'DeviceID': 'D000197',
#   'IP Address': '173.135.78.201',
#   'MerchantID': 'M009',
#   'Channel': 'ATM',
#   'CustomerAge': 19,
#   'CustomerOccupation': 'Student',
#   'TransactionDuration': 117,
#   'LoginAttempts': 1,
#   'AccountBalance': 241.79,
#   'PreviousTransactionDate': '2024-11-04 08:08:03'},
#  {'TransactionID': 'TX000045',
#   'AccountID': 'AC00011',
#   'TransactionAmount': 304.31,
#   'TransactionDate': '2023-07-26 16:52:28',
#   'TransactionType': 'Debit',
#   'Location': 'Louisville',
#   'DeviceID': 'D000685',
#   'IP Address': '77.208.193.198',
#   'MerchantID': 'M005',
#   'Channel': 'Branch',
#   'CustomerAge': 27,
#   'CustomerOccupation': 'Student',
#   'TransactionDuration': 33,
#   'LoginAttempts': 1,
#   'AccountBalance': 868.61,
#   'PreviousTransactionDate': '2024-11-04 08:09:53'},
#  {'TransactionID': 'TX000046',
#   'AccountID': 'AC00401',
#   'TransactionAmount': 435.27,
#   'TransactionDate': '2023-10-04 17:49:29',
#   'TransactionType': 'Debit',
#   'Location': 'Chicago',
#   'DeviceID': 'D000297',
#   'IP Address': '197.162.55.147',
#   'MerchantID': 'M051',
#   'Channel': 'Branch',
#   'CustomerAge': 74,
#   'CustomerOccupation': 'Retired',
#   'TransactionDuration': 90,
#   'LoginAttempts': 1,
#   'AccountBalance': 4673.28,
#   'PreviousTransactionDate': '2024-11-04 08:11:12'},
#  {'TransactionID': 'TX000047',
#   'AccountID': 'AC00282',
#   'TransactionAmount': 164.49,
#   'TransactionDate': '2023-12-13 16:01:38',
#   'TransactionType': 'Debit',
#   'Location': 'Baltimore',
#   'DeviceID': 'D000103',
#   'IP Address': '113.115.81.178',
#   'MerchantID': 'M070',
#   'Channel': 'Branch',
#   'CustomerAge': 26,
#   'CustomerOccupation': 'Student',
#   'TransactionDuration': 75,
#   'LoginAttempts': 1,
#   'AccountBalance': 1509.27,
#   'PreviousTransactionDate': '2024-11-04 08:10:33'},
#  {'TransactionID': 'TX000048',
#   'AccountID': 'AC00439',
#   'TransactionAmount': 510.24,
#   'TransactionDate': '2023-10-09 16:29:40',
#   'TransactionType': 'Debit',
#   'Location': 'Oklahoma City',
#   'DeviceID': 'D000397',
#   'IP Address': '186.135.2.148',
#   'MerchantID': 'M090',
#   'Channel': 'Online',
#   'CustomerAge': 19,
#   'CustomerOccupation': 'Student',
#   'TransactionDuration': 105,
#   'LoginAttempts': 1,
#   'AccountBalance': 781.7,
#   'PreviousTransactionDate': '2024-11-04 08:11:35'},
#  {'TransactionID': 'TX000049',
#   'AccountID': 'AC00296',
#   'TransactionAmount': 626.9,
#   'TransactionDate': '2023-11-27 16:45:57',
#   'TransactionType': 'Debit',
#   'Location': 'Denver',
#   'DeviceID': 'D000284',
#   'IP Address': '93.146.251.20',
#   'MerchantID': 'M023',
#   'Channel': 'Online',
#   'CustomerAge': 26,
#   'CustomerOccupation': 'Student',
#   'TransactionDuration': 138,
#   'LoginAttempts': 1,
#   'AccountBalance': 265.51,
#   'PreviousTransactionDate': '2024-11-04 08:07:24'},
#  {'TransactionID': 'TX000050',
#   'AccountID': 'AC00471',
#   'TransactionAmount': 22.01,
#   'TransactionDate': '2023-03-27 16:45:18',
#   'TransactionType': 'Credit',
#   'Location': 'Sacramento',
#   'DeviceID': 'D000304',
#   'IP Address': '124.6.134.78',
#   'MerchantID': 'M055',
#   'Channel': 'Online',
#   'CustomerAge': 41,
#   'CustomerOccupation': 'Engineer',
#   'TransactionDuration': 175,
#   'LoginAttempts': 1,
#   'AccountBalance': 1335.09,
#   'PreviousTransactionDate': '2024-11-04 08:06:31'},
#  {'TransactionID': 'TX000051',
#   'AccountID': 'AC00159',
#   'TransactionAmount': 425.34,
#   'TransactionDate': '2023-02-13 16:59:39',
#   'TransactionType': 'Credit',
#   'Location': 'Kansas City',
#   'DeviceID': 'D000661',
#   'IP Address': '139.23.212.102',
#   'MerchantID': 'M040',
#   'Channel': 'Online',
#   'CustomerAge': 69,
#   'CustomerOccupation': 'Retired',
#   'TransactionDuration': 121,
#   'LoginAttempts': 1,
#   'AccountBalance': 3907.54,
#   'PreviousTransactionDate': '2024-11-04 08:07:07'},
#  {'TransactionID': 'TX000052',
#   'AccountID': 'AC00482',
#   'TransactionAmount': 424.56,
#   'TransactionDate': '2023-02-21 17:45:55',
#   'TransactionType': 'Debit',
#   'Location': 'Omaha',
#   'DeviceID': 'D000598',
#   'IP Address': '179.43.245.131',
#   'MerchantID': 'M015',
#   'Channel': 'Online',
#   'CustomerAge': 51,
#   'CustomerOccupation': 'Engineer',
#   'TransactionDuration': 264,
#   'LoginAttempts': 1,
#   'AccountBalance': 5183.85,
#   'PreviousTransactionDate': '2024-11-04 08:09:02'},
#  {'TransactionID': 'TX000053',
#   'AccountID': 'AC00115',
#   'TransactionAmount': 85.43,
#   'TransactionDate': '2023-06-07 16:45:34',
#   'TransactionType': 'Debit',
#   'Location': 'Virginia Beach',
#   'DeviceID': 'D000235',
#   'IP Address': '194.174.252.1',
#   'MerchantID': 'M078',
#   'Channel': 'Branch',
#   'CustomerAge': 67,
#   'CustomerOccupation': 'Doctor',
#   'TransactionDuration': 145,
#   'LoginAttempts': 1,
#   'AccountBalance': 14904.9,
#   'PreviousTransactionDate': '2024-11-04 08:06:45'},
#  {'TransactionID': 'TX000054',
#   'AccountID': 'AC00055',
#   'TransactionAmount': 169.5,
#   'TransactionDate': '2023-09-07 16:51:27',
#   'TransactionType': 'Debit',
#   'Location': 'San Diego',
#   'DeviceID': 'D000442',
#   'IP Address': '42.219.228.159',
#   'MerchantID': 'M036',
#   'Channel': 'Branch',
#   'CustomerAge': 28,
#   'CustomerOccupation': 'Student',
#   'TransactionDuration': 142,
#   'LoginAttempts': 1,
#   'AccountBalance': 918.88,
#   'PreviousTransactionDate': '2024-11-04 08:08:58'},
#  {'TransactionID': 'TX000055',
#   'AccountID': 'AC00419',
#   'TransactionAmount': 104.63,
#   'TransactionDate': '2023-03-29 17:47:16',
#   'TransactionType': 'Debit',
#   'Location': 'Omaha',
#   'DeviceID': 'D000642',
#   'IP Address': '186.135.2.148',
#   'MerchantID': 'M095',
#   'Channel': 'ATM',
#   'CustomerAge': 62,
#   'CustomerOccupation': 'Retired',
#   'TransactionDuration': 90,
#   'LoginAttempts': 1,
#   'AccountBalance': 4477.78,
#   'PreviousTransactionDate': '2024-11-04 08:10:42'},
#  {'TransactionID': 'TX000056',
#   'AccountID': 'AC00374',
#   'TransactionAmount': 316.95,
#   'TransactionDate': '2023-08-04 17:53:40',
#   'TransactionType': 'Debit',
#   'Location': 'Mesa',
#   'DeviceID': 'D000013',
#   'IP Address': '81.102.230.41',
#   'MerchantID': 'M052',
#   'Channel': 'Branch',
#   'CustomerAge': 25,
#   'CustomerOccupation': 'Student',
#   'TransactionDuration': 83,
#   'LoginAttempts': 1,
#   'AccountBalance': 1324.03,
#   'PreviousTransactionDate': '2024-11-04 08:09:15'},
#  {'TransactionID': 'TX000057',
#   'AccountID': 'AC00271',
#   'TransactionAmount': 60.54,
#   'TransactionDate': '2023-12-14 17:52:37',
#   'TransactionType': 'Credit',
#   'Location': 'Columbus',
#   'DeviceID': 'D000462',
#   'IP Address': '1.198.76.182',
#   'MerchantID': 'M095',
#   'Channel': 'Branch',
#   'CustomerAge': 57,
#   'CustomerOccupation': 'Retired',
#   'TransactionDuration': 52,
#   'LoginAttempts': 1,
#   'AccountBalance': 3534.93,
#   'PreviousTransactionDate': '2024-11-04 08:09:57'},
#  {'TransactionID': 'TX000058',
#   'AccountID': 'AC00456',
#   'TransactionAmount': 292.56,
#   'TransactionDate': '2023-03-03 17:37:41',
#   'TransactionType': 'Credit',
#   'Location': 'Dallas',
#   'DeviceID': 'D000311',
#   'IP Address': '198.73.211.114',
#   'MerchantID': 'M075',
#   'Channel': 'Branch',
#   'CustomerAge': 68,
#   'CustomerOccupation': 'Retired',
#   'TransactionDuration': 61,
#   'LoginAttempts': 1,
#   'AccountBalance': 4638.37,
#   'PreviousTransactionDate': '2024-11-04 08:07:49'},
#  {'TransactionID': 'TX000059',
#   'AccountID': 'AC00143',
#   'TransactionAmount': 386.52,
#   'TransactionDate': '2023-06-09 16:18:15',
#   'TransactionType': 'Debit',
#   'Location': 'Indianapolis',
#   'DeviceID': 'D000145',
#   'IP Address': '186.54.68.246',
#   'MerchantID': 'M064',
#   'Channel': 'Branch',
#   'CustomerAge': 48,
#   'CustomerOccupation': 'Engineer',
#   'TransactionDuration': 28,
#   'LoginAttempts': 1,
#   'AccountBalance': 5630.61,
#   'PreviousTransactionDate': '2024-11-04 08:07:09'},
#  {'TransactionID': 'TX000060',
#   'AccountID': 'AC00427',
#   'TransactionAmount': 112.07,
#   'TransactionDate': '2023-10-02 16:35:22',
#   'TransactionType': 'Debit',
#   'Location': 'Kansas City',
#   'DeviceID': 'D000089',
#   'IP Address': '198.166.198.233',
#   'MerchantID': 'M064',
#   'Channel': 'Branch',
#   'CustomerAge': 23,
#   'CustomerOccupation': 'Student',
#   'TransactionDuration': 51,
#   'LoginAttempts': 1,
#   'AccountBalance': 930.3,
#   'PreviousTransactionDate': '2024-11-04 08:11:37'},
#  {'TransactionID': 'TX000061',
#   'AccountID': 'AC00438',
#   'TransactionAmount': 568.52,
#   'TransactionDate': '2023-10-06 18:44:37',
#   'TransactionType': 'Debit',
#   'Location': 'Indianapolis',
#   'DeviceID': 'D000233',
#   'IP Address': '27.143.109.203',
#   'MerchantID': 'M094',
#   'Channel': 'ATM',
#   'CustomerAge': 46,
#   'CustomerOccupation': 'Engineer',
#   'TransactionDuration': 152,
#   'LoginAttempts': 1,
#   'AccountBalance': 5499.91,
#   'PreviousTransactionDate': '2024-11-04 08:06:25'},
#  {'TransactionID': 'TX000062',
#   'AccountID': 'AC00002',
#   'TransactionAmount': 263.99,
#   'TransactionDate': '2023-05-16 16:07:30',
#   'TransactionType': 'Debit',
#   'Location': 'Dallas',
#   'DeviceID': 'D000285',
#   'IP Address': '7.146.35.122',
#   'MerchantID': 'M087',
#   'Channel': 'Branch',
#   'CustomerAge': 79,
#   'CustomerOccupation': 'Retired',
#   'TransactionDuration': 227,
#   'LoginAttempts': 2,
#   'AccountBalance': 4175.02,
#   'PreviousTransactionDate': '2024-11-04 08:11:03'},
#  {'TransactionID': 'TX000063',
#   'AccountID': 'AC00425',
#   'TransactionAmount': 349.64,
#   'TransactionDate': '2023-11-07 16:48:23',
#   'TransactionType': 'Debit',
#   'Location': 'Las Vegas',
#   'DeviceID': 'D000516',
#   'IP Address': '9.230.41.239',
#   'MerchantID': 'M097',
#   'Channel': 'Online',
#   'CustomerAge': 48,
#   'CustomerOccupation': 'Engineer',
#   'TransactionDuration': 226,
#   'LoginAttempts': 1,
#   'AccountBalance': 6651.62,
#   'PreviousTransactionDate': '2024-11-04 08:08:09'},
#  {'TransactionID': 'TX000064',
#   'AccountID': 'AC00325',
#   'TransactionAmount': 601.4,
#   'TransactionDate': '2023-05-30 17:43:25',
#   'TransactionType': 'Credit',
#   'Location': 'Philadelphia',
#   'DeviceID': 'D000548',
#   'IP Address': '125.225.212.244',
#   'MerchantID': 'M001',
#   'Channel': 'Branch',
#   'CustomerAge': 56,
#   'CustomerOccupation': 'Engineer',
#   'TransactionDuration': 104,
#   'LoginAttempts': 1,
#   'AccountBalance': 8458.29,
#   'PreviousTransactionDate': '2024-11-04 08:08:01'},
#  {'TransactionID': 'TX000065',
#   'AccountID': 'AC00434',
#   'TransactionAmount': 5.77,
#   'TransactionDate': '2023-11-02 16:01:40',
#   'TransactionType': 'Debit',
#   'Location': 'Charlotte',
#   'DeviceID': 'D000461',
#   'IP Address': '155.164.18.235',
#   'MerchantID': 'M071',
#   'Channel': 'Online',
#   'CustomerAge': 50,
#   'CustomerOccupation': 'Doctor',
#   'TransactionDuration': 124,
#   'LoginAttempts': 1,
#   'AccountBalance': 13988.12,
#   'PreviousTransactionDate': '2024-11-04 08:11:32'},
#  {'TransactionID': 'TX000066',
#   'AccountID': 'AC00242',
#   'TransactionAmount': 201.33,
#   'TransactionDate': '2023-03-29 17:00:31',
#   'TransactionType': 'Credit',
#   'Location': 'Nashville',
#   'DeviceID': 'D000098',
#   'IP Address': '145.246.171.225',
#   'MerchantID': 'M003',
#   'Channel': 'Branch',
#   'CustomerAge': 42,
#   'CustomerOccupation': 'Engineer',
#   'TransactionDuration': 186,
#   'LoginAttempts': 1,
#   'AccountBalance': 2585.07,
#   'PreviousTransactionDate': '2024-11-04 08:11:41'},
#  {'TransactionID': 'TX000067',
#   'AccountID': 'AC00319',
#   'TransactionAmount': 298.42,
#   'TransactionDate': '2023-04-25 16:11:24',
#   'TransactionType': 'Debit',
#   'Location': 'Indianapolis',
#   'DeviceID': 'D000435',
#   'IP Address': '92.214.76.157',
#   'MerchantID': 'M005',
#   'Channel': 'Branch',
#   'CustomerAge': 56,
#   'CustomerOccupation': 'Retired',
#   'TransactionDuration': 225,
#   'LoginAttempts': 1,
#   'AccountBalance': 3014.75,
#   'PreviousTransactionDate': '2024-11-04 08:10:12'},
#  {'TransactionID': 'TX000068',
#   'AccountID': 'AC00460',
#   'TransactionAmount': 521.06,
#   'TransactionDate': '2023-04-18 18:40:47',
#   'TransactionType': 'Debit',
#   'Location': 'Albuquerque',
#   'DeviceID': 'D000305',
#   'IP Address': '131.41.45.13',
#   'MerchantID': 'M063',
#   'Channel': 'Branch',
#   'CustomerAge': 25,
#   'CustomerOccupation': 'Student',
#   'TransactionDuration': 128,
#   'LoginAttempts': 1,
#   'AccountBalance': 1951.42,
#   'PreviousTransactionDate': '2024-11-04 08:12:10'},
#  {'TransactionID': 'TX000069',
#   'AccountID': 'AC00461',
#   'TransactionAmount': 117.28,
#   'TransactionDate': '2023-02-09 16:34:53',
#   'TransactionType': 'Credit',
#   'Location': 'Austin',
#   'DeviceID': 'D000128',
#   'IP Address': '46.150.175.171',
#   'MerchantID': 'M057',
#   'Channel': 'Online',
#   'CustomerAge': 60,
#   'CustomerOccupation': 'Engineer',
#   'TransactionDuration': 16,
#   'LoginAttempts': 1,
#   'AccountBalance': 3665.77,
#   'PreviousTransactionDate': '2024-11-04 08:07:11'},
#  {'TransactionID': 'TX000070',
#   'AccountID': 'AC00395',
#   'TransactionAmount': 189.12,
#   'TransactionDate': '2023-11-13 16:42:28',
#   'TransactionType': 'Credit',
#   'Location': 'Indianapolis',
#   'DeviceID': 'D000684',
#   'IP Address': '125.89.163.224',
#   'MerchantID': 'M040',
#   'Channel': 'Branch',
#   'CustomerAge': 32,
#   'CustomerOccupation': 'Engineer',
#   'TransactionDuration': 103,
#   'LoginAttempts': 1,
#   'AccountBalance': 977.01,
#   'PreviousTransactionDate': '2024-11-04 08:08:42'},
#  {'TransactionID': 'TX000071',
#   'AccountID': 'AC00217',
#   'TransactionAmount': 133.55,
#   'TransactionDate': '2023-07-18 16:12:00',
#   'TransactionType': 'Debit',
#   'Location': 'Atlanta',
#   'DeviceID': 'D000201',
#   'IP Address': '40.226.196.34',
#   'MerchantID': 'M091',
#   'Channel': 'ATM',
#   'CustomerAge': 44,
#   'CustomerOccupation': 'Engineer',
#   'TransactionDuration': 220,
#   'LoginAttempts': 1,
#   'AccountBalance': 3846.28,
#   'PreviousTransactionDate': '2024-11-04 08:10:18'},
#  {'TransactionID': 'TX000072',
#   'AccountID': 'AC00053',
#   'TransactionAmount': 143.21,
#   'TransactionDate': '2023-01-13 17:00:16',
#   'TransactionType': 'Debit',
#   'Location': 'Dallas',
#   'DeviceID': 'D000410',
#   'IP Address': '65.164.3.100',
#   'MerchantID': 'M066',
#   'Channel': 'Online',
#   'CustomerAge': 35,
#   'CustomerOccupation': 'Engineer',
#   'TransactionDuration': 135,
#   'LoginAttempts': 1,
#   'AccountBalance': 6374.82,
#   'PreviousTransactionDate': '2024-11-04 08:09:26'},
#  {'TransactionID': 'TX000073',
#   'AccountID': 'AC00282',
#   'TransactionAmount': 24.77,
#   'TransactionDate': '2023-07-04 18:20:33',
#   'TransactionType': 'Debit',
#   'Location': 'Boston',
#   'DeviceID': 'D000180',
#   'IP Address': '9.230.41.239',
#   'MerchantID': 'M070',
#   'Channel': 'ATM',
#   'CustomerAge': 62,
#   'CustomerOccupation': 'Retired',
#   'TransactionDuration': 55,
#   'LoginAttempts': 1,
#   'AccountBalance': 5866.01,
#   'PreviousTransactionDate': '2024-11-04 08:12:15'},
#  {'TransactionID': 'TX000074',
#   'AccountID': 'AC00110',
#   'TransactionAmount': 233.92,
#   'TransactionDate': '2023-10-20 16:54:28',
#   'TransactionType': 'Credit',
#   'Location': 'Jacksonville',
#   'DeviceID': 'D000295',
#   'IP Address': '152.140.239.181',
#   'MerchantID': 'M046',
#   'Channel': 'Online',
#   'CustomerAge': 26,
#   'CustomerOccupation': 'Student',
#   'TransactionDuration': 280,
#   'LoginAttempts': 1,
#   'AccountBalance': 6537.62,
#   'PreviousTransactionDate': '2024-11-04 08:08:45'},
#  {'TransactionID': 'TX000075',
#   'AccountID': 'AC00265',
#   'TransactionAmount': 1212.51,
#   'TransactionDate': '2023-10-04 16:36:29',
#   'TransactionType': 'Debit',
#   'Location': 'Indianapolis',
#   'DeviceID': 'D000231',
#   'IP Address': '193.83.0.183',
#   'MerchantID': 'M036',
#   'Channel': 'Branch',
#   'CustomerAge': 20,
#   'CustomerOccupation': 'Student',
#   'TransactionDuration': 24,
#   'LoginAttempts': 1,
#   'AccountBalance': 605.95,
#   'PreviousTransactionDate': '2024-11-04 08:06:51'},
#  {'TransactionID': 'TX000076',
#   'AccountID': 'AC00239',
#   'TransactionAmount': 232.12,
#   'TransactionDate': '2023-12-28 17:31:03',
#   'TransactionType': 'Debit',
#   'Location': 'Omaha',
#   'DeviceID': 'D000073',
#   'IP Address': '156.173.170.140',
#   'MerchantID': 'M066',
#   'Channel': 'ATM',
#   'CustomerAge': 37,
#   'CustomerOccupation': 'Engineer',
#   'TransactionDuration': 51,
#   'LoginAttempts': 1,
#   'AccountBalance': 6689.87,
#   'PreviousTransactionDate': '2024-11-04 08:09:17'},
#  {'TransactionID': 'TX000077',
#   'AccountID': 'AC00007',
#   'TransactionAmount': 162.63,
#   'TransactionDate': '2023-06-12 17:53:52',
#   'TransactionType': 'Debit',
#   'Location': 'Kansas City',
#   'DeviceID': 'D000070',
#   'IP Address': '60.153.124.80',
#   'MerchantID': 'M060',
#   'Channel': 'Online',
#   'CustomerAge': 22,
#   'CustomerOccupation': 'Student',
#   'TransactionDuration': 113,
#   'LoginAttempts': 1,
#   'AccountBalance': 634.17,
#   'PreviousTransactionDate': '2024-11-04 08:08:22'},
#  {'TransactionID': 'TX000078',
#   'AccountID': 'AC00022',
#   'TransactionAmount': 91.53,
#   'TransactionDate': '2023-03-13 16:32:12',
#   'TransactionType': 'Debit',
#   'Location': 'Milwaukee',
#   'DeviceID': 'D000363',
#   'IP Address': '94.37.250.128',
#   'MerchantID': 'M095',
#   'Channel': 'Branch',
#   'CustomerAge': 44,
#   'CustomerOccupation': 'Doctor',
#   'TransactionDuration': 69,
#   'LoginAttempts': 1,
#   'AccountBalance': 14676.05,
#   'PreviousTransactionDate': '2024-11-04 08:11:36'},
#  {'TransactionID': 'TX000079',
#   'AccountID': 'AC00464',
#   'TransactionAmount': 120.29,
#   'TransactionDate': '2023-12-18 18:46:27',
#   'TransactionType': 'Debit',
#   'Location': 'Miami',
#   'DeviceID': 'D000561',
#   'IP Address': '162.198.218.92',
#   'MerchantID': 'M045',
#   'Channel': 'Branch',
#   'CustomerAge': 19,
#   'CustomerOccupation': 'Student',
#   'TransactionDuration': 77,
#   'LoginAttempts': 1,
#   'AccountBalance': 1362.39,
#   'PreviousTransactionDate': '2024-11-04 08:06:50'},
#  {'TransactionID': 'TX000080',
#   'AccountID': 'AC00014',
#   'TransactionAmount': 174.25,
#   'TransactionDate': '2023-07-17 18:54:31',
#   'TransactionType': 'Debit',
#   'Location': 'Seattle',
#   'DeviceID': 'D000375',
#   'IP Address': '130.92.201.49',
#   'MerchantID': 'M032',
#   'Channel': 'Online',
#   'CustomerAge': 50,
#   'CustomerOccupation': 'Doctor',
#   'TransactionDuration': 67,
#   'LoginAttempts': 1,
#   'AccountBalance': 10528.34,
#   'PreviousTransactionDate': '2024-11-04 08:10:29'},
#  {'TransactionID': 'TX000081',
#   'AccountID': 'AC00406',
#   'TransactionAmount': 183.71,
#   'TransactionDate': '2023-06-19 18:22:10',
#   'TransactionType': 'Debit',
#   'Location': 'Denver',
#   'DeviceID': 'D000488',
#   'IP Address': '86.103.2.29',
#   'MerchantID': 'M074',
#   'Channel': 'ATM',
#   'CustomerAge': 38,
#   'CustomerOccupation': 'Engineer',
#   'TransactionDuration': 102,
#   'LoginAttempts': 1,
#   'AccountBalance': 552.52,
#   'PreviousTransactionDate': '2024-11-04 08:09:51'},
#  {'TransactionID': 'TX000082',
#   'AccountID': 'AC00445',
#   'TransactionAmount': 345.39,
#   'TransactionDate': '2023-10-23 17:13:57',
#   'TransactionType': 'Credit',
#   'Location': 'Phoenix',
#   'DeviceID': 'D000097',
#   'IP Address': '131.41.45.13',
#   'MerchantID': 'M081',
#   'Channel': 'Online',
#   'CustomerAge': 58,
#   'CustomerOccupation': 'Engineer',
#   'TransactionDuration': 80,
#   'LoginAttempts': 1,
#   'AccountBalance': 6451.96,
#   'PreviousTransactionDate': '2024-11-04 08:08:16'},
#  {'TransactionID': 'TX000083',
#   'AccountID': 'AC00236',
#   'TransactionAmount': 922.55,
#   'TransactionDate': '2023-01-23 16:32:48',
#   'TransactionType': 'Debit',
#   'Location': 'Detroit',
#   'DeviceID': 'D000206',
#   'IP Address': '21.97.154.92',
#   'MerchantID': 'M004',
#   'Channel': 'ATM',
#   'CustomerAge': 63,
#   'CustomerOccupation': 'Retired',
#   'TransactionDuration': 87,
#   'LoginAttempts': 1,
#   'AccountBalance': 4715.84,
#   'PreviousTransactionDate': '2024-11-04 08:11:07'},
#  {'TransactionID': 'TX000084',
#   'AccountID': 'AC00220',
#   'TransactionAmount': 259.91,
#   'TransactionDate': '2023-11-06 16:34:10',
#   'TransactionType': 'Debit',
#   'Location': 'Denver',
#   'DeviceID': 'D000616',
#   'IP Address': '36.13.239.172',
#   'MerchantID': 'M028',
#   'Channel': 'Online',
#   'CustomerAge': 49,
#   'CustomerOccupation': 'Doctor',
#   'TransactionDuration': 170,
#   'LoginAttempts': 1,
#   'AccountBalance': 7176.86,
#   'PreviousTransactionDate': '2024-11-04 08:09:38'},
#  {'TransactionID': 'TX000085',
#   'AccountID': 'AC00140',
#   'TransactionAmount': 154.71,
#   'TransactionDate': '2023-07-03 16:40:24',
#   'TransactionType': 'Debit',
#   'Location': 'San Diego',
#   'DeviceID': 'D000494',
#   'IP Address': '167.104.180.235',
#   'MerchantID': 'M030',
#   'Channel': 'Online',
#   'CustomerAge': 34,
#   'CustomerOccupation': 'Doctor',
#   'TransactionDuration': 157,
#   'LoginAttempts': 1,
#   'AccountBalance': 1523.72,
#   'PreviousTransactionDate': '2024-11-04 08:09:42'},
#  {'TransactionID': 'TX000086',
#   'AccountID': 'AC00098',
#   'TransactionAmount': 1340.19,
#   'TransactionDate': '2023-09-29 17:22:10',
#   'TransactionType': 'Credit',
#   'Location': 'Austin',
#   'DeviceID': 'D000574',
#   'IP Address': '165.114.224.47',
#   'MerchantID': 'M012',
#   'Channel': 'Online',
#   'CustomerAge': 54,
#   'CustomerOccupation': 'Engineer',
#   'TransactionDuration': 30,
#   'LoginAttempts': 1,
#   'AccountBalance': 8654.28,
#   'PreviousTransactionDate': '2024-11-04 08:06:53'},
#  {'TransactionID': 'TX000087',
#   'AccountID': 'AC00303',
#   'TransactionAmount': 24.56,
#   'TransactionDate': '2023-10-20 17:27:35',
#   'TransactionType': 'Debit',
#   'Location': 'Mesa',
#   'DeviceID': 'D000428',
#   'IP Address': '16.131.3.140',
#   'MerchantID': 'M033',
#   'Channel': 'Branch',
#   'CustomerAge': 64,
#   'CustomerOccupation': 'Doctor',
#   'TransactionDuration': 69,
#   'LoginAttempts': 1,
#   'AccountBalance': 9869.93,
#   'PreviousTransactionDate': '2024-11-04 08:12:05'},
#  {'TransactionID': 'TX000088',
#   'AccountID': 'AC00373',
#   'TransactionAmount': 568.07,
#   'TransactionDate': '2023-08-28 17:03:53',
#   'TransactionType': 'Debit',
#   'Location': 'Washington',
#   'DeviceID': 'D000018',
#   'IP Address': '8.243.4.138',
#   'MerchantID': 'M054',
#   'Channel': 'ATM',
#   'CustomerAge': 48,
#   'CustomerOccupation': 'Doctor',
#   'TransactionDuration': 115,
#   'LoginAttempts': 1,
#   'AccountBalance': 10556.81,
#   'PreviousTransactionDate': '2024-11-04 08:07:32'},
#  {'TransactionID': 'TX000089',
#   'AccountID': 'AC00438',
#   'TransactionAmount': 9.61,
#   'TransactionDate': '2023-06-22 18:37:29',
#   'TransactionType': 'Credit',
#   'Location': 'San Diego',
#   'DeviceID': 'D000453',
#   'IP Address': '132.127.5.187',
#   'MerchantID': 'M043',
#   'Channel': 'Online',
#   'CustomerAge': 58,
#   'CustomerOccupation': 'Doctor',
#   'TransactionDuration': 179,
#   'LoginAttempts': 1,
#   'AccountBalance': 12883.91,
#   'PreviousTransactionDate': '2024-11-04 08:09:10'},
#  {'TransactionID': 'TX000090',
#   'AccountID': 'AC00437',
#   'TransactionAmount': 392.96,
#   'TransactionDate': '2023-11-20 16:28:09',
#   'TransactionType': 'Debit',
#   'Location': 'Kansas City',
#   'DeviceID': 'D000141',
#   'IP Address': '186.54.68.246',
#   'MerchantID': 'M022',
#   'Channel': 'Online',
#   'CustomerAge': 24,
#   'CustomerOccupation': 'Student',
#   'TransactionDuration': 100,
#   'LoginAttempts': 1,
#   'AccountBalance': 791.65,
#   'PreviousTransactionDate': '2024-11-04 08:08:38'},
#  {'TransactionID': 'TX000091',
#   'AccountID': 'AC00106',
#   'TransactionAmount': 716.93,
#   'TransactionDate': '2023-09-14 16:49:33',
#   'TransactionType': 'Credit',
#   'Location': 'Milwaukee',
#   'DeviceID': 'D000322',
#   'IP Address': '101.223.82.253',
#   'MerchantID': 'M052',
#   'Channel': 'Online',
#   'CustomerAge': 60,
#   'CustomerOccupation': 'Retired',
#   'TransactionDuration': 34,
#   'LoginAttempts': 1,
#   'AccountBalance': 4064.02,
#   'PreviousTransactionDate': '2024-11-04 08:08:12'},
#  {'TransactionID': 'TX000092',
#   'AccountID': 'AC00310',
#   'TransactionAmount': 223.85,
#   'TransactionDate': '2023-10-02 16:36:10',
#   'TransactionType': 'Debit',
#   'Location': 'Kansas City',
#   'DeviceID': 'D000481',
#   'IP Address': '133.223.159.151',
#   'MerchantID': 'M009',
#   'Channel': 'ATM',
#   'CustomerAge': 53,
#   'CustomerOccupation': 'Engineer',
#   'TransactionDuration': 55,
#   'LoginAttempts': 4,
#   'AccountBalance': 2929.91,
#   'PreviousTransactionDate': '2024-11-04 08:08:01'},
#  {'TransactionID': 'TX000093',
#   'AccountID': 'AC00149',
#   'TransactionAmount': 230.66,
#   'TransactionDate': '2023-03-27 18:16:04',
#   'TransactionType': 'Debit',
#   'Location': 'Houston',
#   'DeviceID': 'D000526',
#   'IP Address': '60.43.160.195',
#   'MerchantID': 'M049',
#   'Channel': 'Branch',
#   'CustomerAge': 21,
#   'CustomerOccupation': 'Student',
#   'TransactionDuration': 135,
#   'LoginAttempts': 1,
#   'AccountBalance': 618.05,
#   'PreviousTransactionDate': '2024-11-04 08:10:44'},
#  {'TransactionID': 'TX000094',
#   'AccountID': 'AC00373',
#   'TransactionAmount': 442.12,
#   'TransactionDate': '2023-12-21 16:37:03',
#   'TransactionType': 'Debit',
#   'Location': 'Los Angeles',
#   'DeviceID': 'D000645',
#   'IP Address': '168.36.49.167',
#   'MerchantID': 'M047',
#   'Channel': 'Online',
#   'CustomerAge': 19,
#   'CustomerOccupation': 'Student',
#   'TransactionDuration': 260,
#   'LoginAttempts': 1,
#   'AccountBalance': 1375.8,
#   'PreviousTransactionDate': '2024-11-04 08:08:21'},
#  {'TransactionID': 'TX000095',
#   'AccountID': 'AC00425',
#   'TransactionAmount': 644.17,
#   'TransactionDate': '2023-03-02 16:05:09',
#   'TransactionType': 'Debit',
#   'Location': 'San Antonio',
#   'DeviceID': 'D000178',
#   'IP Address': '165.38.56.205',
#   'MerchantID': 'M093',
#   'Channel': 'ATM',
#   'CustomerAge': 29,
#   'CustomerOccupation': 'Engineer',
#   'TransactionDuration': 72,
#   'LoginAttempts': 1,
#   'AccountBalance': 1143.52,
#   'PreviousTransactionDate': '2024-11-04 08:08:04'},
#  {'TransactionID': 'TX000096',
#   'AccountID': 'AC00010',
#   'TransactionAmount': 508.68,
#   'TransactionDate': '2023-06-26 16:16:50',
#   'TransactionType': 'Credit',
#   'Location': 'Mesa',
#   'DeviceID': 'D000622',
#   'IP Address': '193.108.17.115',
#   'MerchantID': 'M048',
#   'Channel': 'Branch',
#   'CustomerAge': 51,
#   'CustomerOccupation': 'Engineer',
#   'TransactionDuration': 127,
#   'LoginAttempts': 1,
#   'AccountBalance': 7708.41,
#   'PreviousTransactionDate': '2024-11-04 08:09:32'},
#  {'TransactionID': 'TX000097',
#   'AccountID': 'AC00348',
#   'TransactionAmount': 858.63,
#   'TransactionDate': '2023-04-18 17:27:23',
#   'TransactionType': 'Credit',
#   'Location': 'San Francisco',
#   'DeviceID': 'D000019',
#   'IP Address': '175.230.206.232',
#   'MerchantID': 'M002',
#   'Channel': 'Branch',
#   'CustomerAge': 27,
#   'CustomerOccupation': 'Student',
#   'TransactionDuration': 185,
#   'LoginAttempts': 1,
#   'AccountBalance': 1872.96,
#   'PreviousTransactionDate': '2024-11-04 08:10:47'},
#  {'TransactionID': 'TX000098',
#   'AccountID': 'AC00011',
#   'TransactionAmount': 25.36,
#   'TransactionDate': '2023-07-17 17:08:24',
#   'TransactionType': 'Debit',
#   'Location': 'Louisville',
#   'DeviceID': 'D000192',
#   'IP Address': '62.152.134.92',
#   'MerchantID': 'M007',
#   'Channel': 'ATM',
#   'CustomerAge': 57,
#   'CustomerOccupation': 'Engineer',
#   'TransactionDuration': 78,
#   'LoginAttempts': 1,
#   'AccountBalance': 201.04,
#   'PreviousTransactionDate': '2024-11-04 08:11:05'},
#  {'TransactionID': 'TX000099',
#   'AccountID': 'AC00453',
#   'TransactionAmount': 147.62,
#   'TransactionDate': '2023-09-01 17:26:02',
#   'TransactionType': 'Debit',
#   'Location': 'Charlotte',
#   'DeviceID': 'D000093',
#   'IP Address': '149.84.108.18',
#   'MerchantID': 'M028',
#   'Channel': 'Branch',
#   'CustomerAge': 71,
#   'CustomerOccupation': 'Retired',
#   'TransactionDuration': 133,
#   'LoginAttempts': 1,
#   'AccountBalance': 2115.8,
#   'PreviousTransactionDate': '2024-11-04 08:07:22'},
#  {'TransactionID': 'TX000100',
#   'AccountID': 'AC00178',
#   'TransactionAmount': 115.02,
#   'TransactionDate': '2023-09-11 16:19:04',
#   'TransactionType': 'Debit',
#   'Location': 'San Antonio',
#   'DeviceID': 'D000528',
# ...
#   'PreviousTransactionDate': '2024-11-04 08:09:56'},
#  {'TransactionID': 'TX000968',
#   'AccountID': 'AC00185',
#   'TransactionAmount': 21.41,
#   'TransactionDate': '2023-12-04 16:27:03',
#   'TransactionType': 'Debit',
#   'Location': 'Louisville',
#   'DeviceID': 'D000092',
#   'IP Address': '195.164.171.146',
#   'MerchantID': 'M062',
#   'Channel': 'Online',
#   'CustomerAge': 57,
#   'CustomerOccupation': 'Doctor',
#   'TransactionDuration': 99,
#   'LoginAttempts': 1,
#   'AccountBalance': 658.91,
#   'PreviousTransactionDate': '2024-11-04 08:08:40'},
#  {'TransactionID': 'TX000969',
#   'AccountID': 'AC00487',
#   'TransactionAmount': 278.28,
#   'TransactionDate': '2023-10-02 16:20:52',
#   'TransactionType': 'Debit',
#   'Location': 'Jacksonville',
#   'DeviceID': 'D000038',
#   'IP Address': '148.42.122.1',
#   'MerchantID': 'M097',
#   'Channel': 'Branch',
#   'CustomerAge': 28,
#   'CustomerOccupation': 'Student',
#   'TransactionDuration': 26,
#   'LoginAttempts': 1,
#   'AccountBalance': 1346.88,
#   'PreviousTransactionDate': '2024-11-04 08:07:37'},
#  {'TransactionID': 'TX000970',
#   'AccountID': 'AC00280',
#   'TransactionAmount': 388.1,
#   'TransactionDate': '2023-08-21 18:06:59',
#   'TransactionType': 'Credit',
#   'Location': 'Los Angeles',
#   'DeviceID': 'D000653',
#   'IP Address': '101.90.40.193',
#   'MerchantID': 'M019',
#   'Channel': 'Online',
#   'CustomerAge': 73,
#   'CustomerOccupation': 'Retired',
#   'TransactionDuration': 40,
#   'LoginAttempts': 1,
#   'AccountBalance': 3022.12,
#   'PreviousTransactionDate': '2024-11-04 08:07:32'},
#  {'TransactionID': 'TX000971',
#   'AccountID': 'AC00017',
#   'TransactionAmount': 215.39,
#   'TransactionDate': '2023-06-21 16:23:53',
#   'TransactionType': 'Debit',
#   'Location': 'Detroit',
#   'DeviceID': 'D000409',
#   'IP Address': '196.121.240.10',
#   'MerchantID': 'M019',
#   'Channel': 'ATM',
#   'CustomerAge': 27,
#   'CustomerOccupation': 'Student',
#   'TransactionDuration': 216,
#   'LoginAttempts': 1,
#   'AccountBalance': 1582.55,
#   'PreviousTransactionDate': '2024-11-04 08:11:13'},
#  {'TransactionID': 'TX000972',
#   'AccountID': 'AC00496',
#   'TransactionAmount': 194.37,
#   'TransactionDate': '2023-04-26 17:55:11',
#   'TransactionType': 'Debit',
#   'Location': 'Milwaukee',
#   'DeviceID': 'D000151',
#   'IP Address': '160.160.113.117',
#   'MerchantID': 'M024',
#   'Channel': 'ATM',
#   'CustomerAge': 66,
#   'CustomerOccupation': 'Doctor',
#   'TransactionDuration': 161,
#   'LoginAttempts': 1,
#   'AccountBalance': 14395.88,
#   'PreviousTransactionDate': '2024-11-04 08:09:28'},
#  {'TransactionID': 'TX000973',
#   'AccountID': 'AC00304',
#   'TransactionAmount': 37.7,
#   'TransactionDate': '2023-06-29 16:04:17',
#   'TransactionType': 'Debit',
#   'Location': 'Miami',
#   'DeviceID': 'D000344',
#   'IP Address': '167.67.137.223',
#   'MerchantID': 'M038',
#   'Channel': 'ATM',
#   'CustomerAge': 20,
#   'CustomerOccupation': 'Student',
#   'TransactionDuration': 109,
#   'LoginAttempts': 1,
#   'AccountBalance': 1741.1,
#   'PreviousTransactionDate': '2024-11-04 08:12:08'},
#  {'TransactionID': 'TX000974',
#   'AccountID': 'AC00475',
#   'TransactionAmount': 19.59,
#   'TransactionDate': '2023-06-16 18:47:34',
#   'TransactionType': 'Debit',
#   'Location': 'Charlotte',
#   'DeviceID': 'D000529',
#   'IP Address': '170.54.231.239',
#   'MerchantID': 'M016',
#   'Channel': 'Branch',
#   'CustomerAge': 64,
#   'CustomerOccupation': 'Retired',
#   'TransactionDuration': 122,
#   'LoginAttempts': 1,
#   'AccountBalance': 1061.69,
#   'PreviousTransactionDate': '2024-11-04 08:10:31'},
#  {'TransactionID': 'TX000975',
#   'AccountID': 'AC00111',
#   'TransactionAmount': 81.35,
#   'TransactionDate': '2023-01-23 17:39:08',
#   'TransactionType': 'Debit',
#   'Location': 'Houston',
#   'DeviceID': 'D000242',
#   'IP Address': '205.69.66.135',
#   'MerchantID': 'M028',
#   'Channel': 'Online',
#   'CustomerAge': 41,
#   'CustomerOccupation': 'Engineer',
#   'TransactionDuration': 103,
#   'LoginAttempts': 1,
#   'AccountBalance': 7192.45,
#   'PreviousTransactionDate': '2024-11-04 08:07:04'},
#  {'TransactionID': 'TX000976',
#   'AccountID': 'AC00316',
#   'TransactionAmount': 314.54,
#   'TransactionDate': '2023-09-29 16:34:03',
#   'TransactionType': 'Credit',
#   'Location': 'Virginia Beach',
#   'DeviceID': 'D000168',
#   'IP Address': '116.237.223.50',
#   'MerchantID': 'M035',
#   'Channel': 'Branch',
#   'CustomerAge': 58,
#   'CustomerOccupation': 'Engineer',
#   'TransactionDuration': 228,
#   'LoginAttempts': 1,
#   'AccountBalance': 9923.45,
#   'PreviousTransactionDate': '2024-11-04 08:11:02'},
#  {'TransactionID': 'TX000977',
#   'AccountID': 'AC00007',
#   'TransactionAmount': 466.64,
#   'TransactionDate': '2023-09-04 16:57:31',
#   'TransactionType': 'Debit',
#   'Location': 'Las Vegas',
#   'DeviceID': 'D000327',
#   'IP Address': '131.41.45.13',
#   'MerchantID': 'M082',
#   'Channel': 'ATM',
#   'CustomerAge': 58,
#   'CustomerOccupation': 'Doctor',
#   'TransactionDuration': 11,
#   'LoginAttempts': 1,
#   'AccountBalance': 10915.11,
#   'PreviousTransactionDate': '2024-11-04 08:09:20'},
#  {'TransactionID': 'TX000978',
#   'AccountID': 'AC00033',
#   'TransactionAmount': 397.01,
#   'TransactionDate': '2023-08-07 17:45:52',
#   'TransactionType': 'Debit',
#   'Location': 'Los Angeles',
#   'DeviceID': 'D000044',
#   'IP Address': '92.180.81.50',
#   'MerchantID': 'M058',
#   'Channel': 'ATM',
#   'CustomerAge': 22,
#   'CustomerOccupation': 'Student',
#   'TransactionDuration': 100,
#   'LoginAttempts': 1,
#   'AccountBalance': 719.52,
#   'PreviousTransactionDate': '2024-11-04 08:06:31'},
#  {'TransactionID': 'TX000979',
#   'AccountID': 'AC00453',
#   'TransactionAmount': 472.48,
#   'TransactionDate': '2023-02-27 17:06:36',
#   'TransactionType': 'Debit',
#   'Location': 'New York',
#   'DeviceID': 'D000149',
#   'IP Address': '11.3.59.231',
#   'MerchantID': 'M099',
#   'Channel': 'Branch',
#   'CustomerAge': 55,
#   'CustomerOccupation': 'Engineer',
#   'TransactionDuration': 87,
#   'LoginAttempts': 1,
#   'AccountBalance': 7128.82,
#   'PreviousTransactionDate': '2024-11-04 08:09:59'},
#  {'TransactionID': 'TX000980',
#   'AccountID': 'AC00147',
#   'TransactionAmount': 67.15,
#   'TransactionDate': '2023-11-20 17:17:05',
#   'TransactionType': 'Debit',
#   'Location': 'Indianapolis',
#   'DeviceID': 'D000661',
#   'IP Address': '191.91.45.159',
#   'MerchantID': 'M001',
#   'Channel': 'Online',
#   'CustomerAge': 59,
#   'CustomerOccupation': 'Doctor',
#   'TransactionDuration': 14,
#   'LoginAttempts': 1,
#   'AccountBalance': 9028.49,
#   'PreviousTransactionDate': '2024-11-04 08:10:53'},
#  {'TransactionID': 'TX000981',
#   'AccountID': 'AC00401',
#   'TransactionAmount': 102.67,
#   'TransactionDate': '2023-05-10 17:41:59',
#   'TransactionType': 'Debit',
#   'Location': 'Albuquerque',
#   'DeviceID': 'D000097',
#   'IP Address': '215.97.143.157',
#   'MerchantID': 'M091',
#   'Channel': 'Branch',
#   'CustomerAge': 79,
#   'CustomerOccupation': 'Retired',
#   'TransactionDuration': 119,
#   'LoginAttempts': 1,
#   'AccountBalance': 4656.94,
#   'PreviousTransactionDate': '2024-11-04 08:06:32'},
#  {'TransactionID': 'TX000982',
#   'AccountID': 'AC00336',
#   'TransactionAmount': 460.09,
#   'TransactionDate': '2023-03-06 17:05:25',
#   'TransactionType': 'Credit',
#   'Location': 'Fresno',
#   'DeviceID': 'D000033',
#   'IP Address': '188.77.83.72',
#   'MerchantID': 'M081',
#   'Channel': 'Online',
#   'CustomerAge': 35,
#   'CustomerOccupation': 'Doctor',
#   'TransactionDuration': 146,
#   'LoginAttempts': 3,
#   'AccountBalance': 6990.64,
#   'PreviousTransactionDate': '2024-11-04 08:08:33'},
#  {'TransactionID': 'TX000983',
#   'AccountID': 'AC00281',
#   'TransactionAmount': 453.49,
#   'TransactionDate': '2023-01-02 16:06:29',
#   'TransactionType': 'Debit',
#   'Location': 'Seattle',
#   'DeviceID': 'D000471',
#   'IP Address': '40.226.196.34',
#   'MerchantID': 'M088',
#   'Channel': 'Branch',
#   'CustomerAge': 66,
#   'CustomerOccupation': 'Doctor',
#   'TransactionDuration': 147,
#   'LoginAttempts': 1,
#   'AccountBalance': 6366.43,
#   'PreviousTransactionDate': '2024-11-04 08:08:56'},
#  {'TransactionID': 'TX000984',
#   'AccountID': 'AC00082',
#   'TransactionAmount': 267.17,
#   'TransactionDate': '2023-08-24 16:56:36',
#   'TransactionType': 'Debit',
#   'Location': 'Seattle',
#   'DeviceID': 'D000638',
#   'IP Address': '161.177.41.214',
#   'MerchantID': 'M100',
#   'Channel': 'ATM',
#   'CustomerAge': 26,
#   'CustomerOccupation': 'Student',
#   'TransactionDuration': 170,
#   'LoginAttempts': 1,
#   'AccountBalance': 1382.62,
#   'PreviousTransactionDate': '2024-11-04 08:07:54'},
#  {'TransactionID': 'TX000985',
#   'AccountID': 'AC00247',
#   'TransactionAmount': 111.26,
#   'TransactionDate': '2023-08-18 17:07:18',
#   'TransactionType': 'Debit',
#   'Location': 'Boston',
#   'DeviceID': 'D000102',
#   'IP Address': '138.220.61.84',
#   'MerchantID': 'M096',
#   'Channel': 'ATM',
#   'CustomerAge': 66,
#   'CustomerOccupation': 'Doctor',
#   'TransactionDuration': 43,
#   'LoginAttempts': 1,
#   'AccountBalance': 14350.11,
#   'PreviousTransactionDate': '2024-11-04 08:07:47'},
#  {'TransactionID': 'TX000986',
#   'AccountID': 'AC00278',
#   'TransactionAmount': 121.17,
#   'TransactionDate': '2023-12-25 17:31:16',
#   'TransactionType': 'Debit',
#   'Location': 'Phoenix',
#   'DeviceID': 'D000573',
#   'IP Address': '155.19.119.0',
#   'MerchantID': 'M053',
#   'Channel': 'ATM',
#   'CustomerAge': 68,
#   'CustomerOccupation': 'Doctor',
#   'TransactionDuration': 158,
#   'LoginAttempts': 1,
#   'AccountBalance': 12990.77,
#   'PreviousTransactionDate': '2024-11-04 08:10:12'},
#  {'TransactionID': 'TX000987',
#   'AccountID': 'AC00176',
#   'TransactionAmount': 213.28,
#   'TransactionDate': '2023-12-25 18:29:05',
#   'TransactionType': 'Debit',
#   'Location': 'Mesa',
#   'DeviceID': 'D000034',
#   'IP Address': '156.134.123.253',
#   'MerchantID': 'M088',
#   'Channel': 'Branch',
#   'CustomerAge': 51,
#   'CustomerOccupation': 'Retired',
#   'TransactionDuration': 94,
#   'LoginAttempts': 1,
#   'AccountBalance': 4835.91,
#   'PreviousTransactionDate': '2024-11-04 08:11:27'},
#  {'TransactionID': 'TX000988',
#   'AccountID': 'AC00159',
#   'TransactionAmount': 187.88,
#   'TransactionDate': '2023-08-10 16:39:44',
#   'TransactionType': 'Debit',
#   'Location': 'Nashville',
#   'DeviceID': 'D000034',
#   'IP Address': '189.198.67.252',
#   'MerchantID': 'M017',
#   'Channel': 'ATM',
#   'CustomerAge': 60,
#   'CustomerOccupation': 'Engineer',
#   'TransactionDuration': 180,
#   'LoginAttempts': 1,
#   'AccountBalance': 2154.58,
#   'PreviousTransactionDate': '2024-11-04 08:10:56'},
#  {'TransactionID': 'TX000989',
#   'AccountID': 'AC00035',
#   'TransactionAmount': 471.88,
#   'TransactionDate': '2023-10-30 18:44:22',
#   'TransactionType': 'Credit',
#   'Location': 'San Jose',
#   'DeviceID': 'D000317',
#   'IP Address': '133.67.250.163',
#   'MerchantID': 'M054',
#   'Channel': 'Online',
#   'CustomerAge': 34,
#   'CustomerOccupation': 'Doctor',
#   'TransactionDuration': 141,
#   'LoginAttempts': 1,
#   'AccountBalance': 14833.34,
#   'PreviousTransactionDate': '2024-11-04 08:07:00'},
#  {'TransactionID': 'TX000990',
#   'AccountID': 'AC00463',
#   'TransactionAmount': 83.79,
#   'TransactionDate': '2023-10-12 16:37:49',
#   'TransactionType': 'Debit',
#   'Location': 'Nashville',
#   'DeviceID': 'D000176',
#   'IP Address': '12.246.170.239',
#   'MerchantID': 'M031',
#   'Channel': 'ATM',
#   'CustomerAge': 57,
#   'CustomerOccupation': 'Engineer',
#   'TransactionDuration': 47,
#   'LoginAttempts': 1,
#   'AccountBalance': 5061.3,
#   'PreviousTransactionDate': '2024-11-04 08:09:05'},
#  {'TransactionID': 'TX000991',
#   'AccountID': 'AC00339',
#   'TransactionAmount': 212.14,
#   'TransactionDate': '2023-08-14 17:28:37',
#   'TransactionType': 'Debit',
#   'Location': 'Austin',
#   'DeviceID': 'D000269',
#   'IP Address': '44.67.137.125',
#   'MerchantID': 'M047',
#   'Channel': 'Branch',
#   'CustomerAge': 72,
#   'CustomerOccupation': 'Retired',
#   'TransactionDuration': 105,
#   'LoginAttempts': 1,
#   'AccountBalance': 7225.06,
#   'PreviousTransactionDate': '2024-11-04 08:08:46'},
#  {'TransactionID': 'TX000992',
#   'AccountID': 'AC00239',
#   'TransactionAmount': 99.16,
#   'TransactionDate': '2023-02-28 17:55:00',
#   'TransactionType': 'Debit',
#   'Location': 'San Francisco',
#   'DeviceID': 'D000573',
#   'IP Address': '84.237.126.96',
#   'MerchantID': 'M045',
#   'Channel': 'Online',
#   'CustomerAge': 79,
#   'CustomerOccupation': 'Retired',
#   'TransactionDuration': 202,
#   'LoginAttempts': 1,
#   'AccountBalance': 2607.58,
#   'PreviousTransactionDate': '2024-11-04 08:10:27'},
#  {'TransactionID': 'TX000993',
#   'AccountID': 'AC00090',
#   'TransactionAmount': 839.33,
#   'TransactionDate': '2023-05-02 16:03:23',
#   'TransactionType': 'Credit',
#   'Location': 'Louisville',
#   'DeviceID': 'D000579',
#   'IP Address': '174.61.77.54',
#   'MerchantID': 'M071',
#   'Channel': 'Branch',
#   'CustomerAge': 60,
#   'CustomerOccupation': 'Doctor',
#   'TransactionDuration': 86,
#   'LoginAttempts': 1,
#   'AccountBalance': 11538.97,
#   'PreviousTransactionDate': '2024-11-04 08:09:21'},
#  {'TransactionID': 'TX000994',
#   'AccountID': 'AC00144',
#   'TransactionAmount': 29.91,
#   'TransactionDate': '2023-07-31 16:26:33',
#   'TransactionType': 'Credit',
#   'Location': 'Philadelphia',
#   'DeviceID': 'D000551',
#   'IP Address': '113.21.93.28',
#   'MerchantID': 'M034',
#   'Channel': 'Online',
#   'CustomerAge': 76,
#   'CustomerOccupation': 'Retired',
#   'TransactionDuration': 43,
#   'LoginAttempts': 3,
#   'AccountBalance': 2834.84,
#   'PreviousTransactionDate': '2024-11-04 08:08:39'},
#  {'TransactionID': 'TX000995',
#   'AccountID': 'AC00488',
#   'TransactionAmount': 4.24,
#   'TransactionDate': '2023-04-17 16:46:31',
#   'TransactionType': 'Debit',
#   'Location': 'San Diego',
#   'DeviceID': 'D000226',
#   'IP Address': '77.208.193.198',
#   'MerchantID': 'M086',
#   'Channel': 'Online',
#   'CustomerAge': 38,
#   'CustomerOccupation': 'Engineer',
#   'TransactionDuration': 38,
#   'LoginAttempts': 1,
#   'AccountBalance': 7822.73,
#   'PreviousTransactionDate': '2024-11-04 08:07:54'},
#  {'TransactionID': 'TX000996',
#   'AccountID': 'AC00039',
#   'TransactionAmount': 50.29,
#   'TransactionDate': '2023-09-18 16:13:38',
#   'TransactionType': 'Credit',
#   'Location': 'Raleigh',
#   'DeviceID': 'D000499',
#   'IP Address': '171.150.178.172',
#   'MerchantID': 'M028',
#   'Channel': 'Online',
#   'CustomerAge': 58,
#   'CustomerOccupation': 'Doctor',
#   'TransactionDuration': 64,
#   'LoginAttempts': 1,
#   'AccountBalance': 7604.9,
#   'PreviousTransactionDate': '2024-11-04 08:07:16'},
#  {'TransactionID': 'TX000997',
#   'AccountID': 'AC00475',
#   'TransactionAmount': 135.85,
#   'TransactionDate': '2023-08-03 17:25:57',
#   'TransactionType': 'Debit',
#   'Location': 'Fresno',
#   'DeviceID': 'D000430',
#   'IP Address': '65.27.212.129',
#   'MerchantID': 'M015',
#   'Channel': 'Online',
#   'CustomerAge': 57,
#   'CustomerOccupation': 'Retired',
#   'TransactionDuration': 269,
#   'LoginAttempts': 1,
#   'AccountBalance': 1480.39,
#   'PreviousTransactionDate': '2024-11-04 08:08:16'},
#  {'TransactionID': 'TX000998',
#   'AccountID': 'AC00368',
#   'TransactionAmount': 368.53,
#   'TransactionDate': '2023-04-03 16:09:09',
#   'TransactionType': 'Debit',
#   'Location': 'Raleigh',
#   'DeviceID': 'D000469',
#   'IP Address': '31.127.129.152',
#   'MerchantID': 'M099',
#   'Channel': 'Branch',
#   'CustomerAge': 68,
#   'CustomerOccupation': 'Doctor',
#   'TransactionDuration': 34,
#   'LoginAttempts': 1,
#   'AccountBalance': 13696.31,
#   'PreviousTransactionDate': '2024-11-04 08:06:56'},
#  {'TransactionID': 'TX000999',
#   'AccountID': 'AC00339',
#   'TransactionAmount': 17.95,
#   'TransactionDate': '2023-06-05 17:22:19',
#   'TransactionType': 'Credit',
#   'Location': 'Sacramento',
#   'DeviceID': 'D000411',
#   'IP Address': '167.164.55.0',
#   'MerchantID': 'M027',
#   'Channel': 'Branch',
#   'CustomerAge': 64,
#   'CustomerOccupation': 'Doctor',
#   'TransactionDuration': 135,
#   'LoginAttempts': 1,
#   'AccountBalance': 12344.9,
#   'PreviousTransactionDate': '2024-11-04 08:09:36'},
#  {'TransactionID': 'TX001000',
#   'AccountID': 'AC00297',
#   'TransactionAmount': 127.8,
#   'TransactionDate': '2023-03-02 16:05:52',
#   'TransactionType': 'Credit',
#   'Location': 'Virginia Beach',
#   'DeviceID': 'D000376',
#   'IP Address': '34.169.232.37',
#   'MerchantID': 'M026',
#   'Channel': 'Branch',
#   'CustomerAge': 31,
#   'CustomerOccupation': 'Engineer',
#   'TransactionDuration': 47,
#   'LoginAttempts': 1,
#   'AccountBalance': 8630.99,
#   'PreviousTransactionDate': '2024-11-04 08:07:02'},
#  ...]

# %%
load_dotenv()

DB_NAME = "Project-1"
COLLECTION_NAME = "Project-1-Data"
CONNECTION_URL = os.getenv('MONGODB_CONNECTION_URL')

# %%
client = pymongo.MongoClient(CONNECTION_URL)
database = client[DB_NAME]
collection = database[COLLECTION_NAME]

# %%
#uploading data to mongodb
rec = collection.insert_many(data)

# %%
type(rec)
# Out:
# pymongo.results.InsertManyResult
